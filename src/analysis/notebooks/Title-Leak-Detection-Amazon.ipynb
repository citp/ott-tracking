# %%
import LeakDetector
import pandas as pd
from glob import glob

# %%
from device_ids import TV_ID_MAP
from log_analysis import get_crawl_parameter
from crawl_ids import CrawlFireTVTop1KMITM
from df_utils import load_df

# %% [markdown]
# ## Load leaks
# - Run the following to detect and pickle leaks
#   - Detect on all crawls: `python2 title_leaks.py`
#   - Detect on a single crawl: `python2 title_leaks.py roku-data-20190508-013650`

# %%
leaks = load_df(CrawlFireTVTop1KMITM, "title_leak")

# %%
from log_analysis import add_domain_column
add_domain_column(leaks)

leaks[leaks.id_type !="Channel name"][['channel_id', 'channel_name', 'id_type', 'encoding', 'search', 'leak_type', 'req_domain']].drop_duplicates()
# Out:
#                                           channel_id  \
# 0  com.amazon.rialto.cordova.webapp.webapp19bc7f4...
# 0  com.amazon.rialto.cordova.webapp.webapp19bc7f4...
# 0  com.amazon.rialto.cordova.webapp.webapp19bc7f4...
# 0                             com.calkins.grahamksat
# 0                                   com.calkins.wral
# 0                                   com.calkins.wral
# 0                                    com.dmr.yuyu.tv
# 0  com.doapps.firetv.mln.MLN_6ae07dcb33ec3b7c814d...
# 0                        com.graytv.android.wsaznews
# 0                            com.hearst.android.kcra
# 0                            com.hearst.android.wcvb
# 0                            com.hearst.android.wcvb
# 0                            com.hearst.android.wdsu
# 0                            com.hearst.android.wdsu
# 0                            com.hearst.android.wpbf
# 0                            com.hearst.android.wpbf
# 0                            com.hearst.android.wpbf
# 0                            com.hearst.android.wyff
# 0                            com.hearst.android.wyff
# 0                            com.hillsongchannel.now
# 0                           com.mylocaltv.kjrhfiretv
# 0                           com.mylocaltv.wptvfiretv
# 0        com.planetdiscover.granite.phone.wkbwfiretv
# 0                                   com.zumobi.msnbc
# 0                                   com.zumobi.msnbc
# 0            net.screenmedia.popcornflix.kids.firetv
# 0            net.screenmedia.popcornflix.kids.firetv
# 0                           tv.accedo.cookingchannel
# 0                           tv.accedo.cookingchannel
# 0                            tv.accedo.travelchannel
# 0                            tv.accedo.travelchannel
# 0                                    tv.clasp.firetv
# 0                                    tv.clasp.firetv
# 0                                   tv.pluto.android
# 0                                   tv.pluto.android
#
#                                  channel_name  \
# 0                    Christian TV for Fire TV
# 0                    Christian TV for Fire TV
# 0                    Christian TV for Fire TV
# 0                                     KSAT TV
# 0                                        WRAL
# 0                                        WRAL
# 0                      Yuyu - Movies &amp; TV
# 0             WTMJ TODAY&#39;s TMJ4 Milwaukee
# 0                                   WSAZ News
# 0          KCRA 3 Sacramento News and Weather
# 0   WCVB NewsCenter 5 Boston News and Weather
# 0   WCVB NewsCenter 5 Boston News and Weather
# 0              WDSU New Orleans News  Weather
# 0              WDSU New Orleans News  Weather
# 0  WPBF 25 - West Palm Beach News and Weather
# 0  WPBF 25 - West Palm Beach News and Weather
# 0  WPBF 25 - West Palm Beach News and Weather
# 0          WYFF 4 Greenville News and weather
# 0          WYFF 4 Greenville News and weather
# 0                        Hillsong Channel NOW
# 0                  KJRH 2 Works For You Tulsa
# 0                WPTV NewsChannel 5 West Palm
# 0              WKBW 7 Eyewitness News Buffalo
# 0                                    NBC News
# 0                                    NBC News
# 0                            Popcornflix Kids
# 0                            Popcornflix Kids
# 0                             Cooking Channel
# 0                             Cooking Channel
# 0                              Travel Channel
# 0                              Travel Channel
# 0               PopcornflixTM- Movies.TV.Free
# 0               PopcornflixTM- Movies.TV.Free
# 0                 Pluto TV - It&#39;s Free TV
# 0                 Pluto TV - It&#39;s Free TV
#
#                                              id_type   encoding  \
# 0                                    imdb_title_ADTV  unencoded
# 0                                    imdb_title_ADTV  unencoded
# 0                                    imdb_title_ADTV  unencoded
# 0                      imdb_title_KSAT-TV Livestream  urlencode
# 0       imdb_title_Severe storms batter central U.S.  urlencode
# 0       imdb_title_Severe storms batter central U.S.  urlencode
# 0                             imdb_title_Mood Indigo  urlencode
# 0            imdb_title_Partly cloudy, cool Saturday  urlencode
# 0                                    imdb_title_SBTV  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                                 imdb_title_NOWCAST  unencoded
# 0                          imdb_title_The Jesus Trek  unencoded
# 0  imdb_title_In the Kitchen with Fireside Grill:...  urlencode
# 0                            imdb_title_To The Point  urlencode
# 0  imdb_title_Graffiti Patio officially opens at ...  urlencode
# 0                       imdb_title_TODAY's Headlines  urlencode
# 0                       imdb_title_TODAY's Headlines  urlencode
# 0                              imdb_title_The Tuxedo  urlencode
# 0                              imdb_title_The Tuxedo  urlencode
# 0                        imdb_title_Raising the Heat  unencoded
# 0                        imdb_title_Raising the Heat  urlencode
# 0                          imdb_title_The Dead Files  unencoded
# 0                          imdb_title_The Dead Files  urlencode
# 0           imdb_title_Planes Trains and Automobiles  urlencode
# 0           imdb_title_Planes Trains and Automobiles  urlencode
# 0                imdb_title_The Adventures of Tintin  urlencode
# 0                imdb_title_The Adventures of Tintin  urlencode
#
#                                               search       leak_type  \
# 0                                               adtv  referrer_leaks
# 0                                               adtv  referrer_leaks
# 0                                               adtv       url_leaks
# 0                                 KSAT-TV Livestream      post_leaks
# 0                  Severe storms batter central U.S.       url_leaks
# 0                  Severe storms batter central U.S.      post_leaks
# 0                                        Mood Indigo       url_leaks
# 0                       Partly cloudy, cool Saturday      post_leaks
# 0                                               sbtv       url_leaks
# 0                                            nowcast       url_leaks
# 0                                            nowcast       url_leaks
# 0                                            nowcast      post_leaks
# 0                                            nowcast       url_leaks
# 0                                            nowcast      post_leaks
# 0                                            nowcast      post_leaks
# 0                                            nowcast       url_leaks
# 0                                            nowcast      post_leaks
# 0                                            nowcast       url_leaks
# 0                                            nowcast      post_leaks
# 0                                     The Jesus Trek      post_leaks
# 0  In the Kitchen with Fireside Grill: Caribbean ...      post_leaks
# 0                                       To The Point      post_leaks
# 0     Graffiti Patio officially opens at Tappo Pizza      post_leaks
# 0                                  TODAY's Headlines       url_leaks
# 0                                  TODAY's Headlines      post_leaks
# 0                                         The Tuxedo       url_leaks
# 0                                         The Tuxedo      post_leaks
# 0                                   Raising the Heat      post_leaks
# 0                                   raising the heat      post_leaks
# 0                                     The Dead Files      post_leaks
# 0                                     the dead files      post_leaks
# 0                      Planes Trains and Automobiles      post_leaks
# 0                      Planes Trains and Automobiles       url_leaks
# 0                           The Adventures of Tintin       url_leaks
# 0                           The Adventures of Tintin       url_leaks
#
#                       req_domain
# 0                       tulix.tv
# 0               christian-tv.org
# 0               christian-tv.org
# 0           google-analytics.com
# 0          scorecardresearch.com
# 0           google-analytics.com
# 0                spotxchange.com
# 0           google-analytics.com
# 0  d27wx7ytq78mow.cloudfront.net
# 0                doubleclick.net
# 0                doubleclick.net
# 0                    parsely.com
# 0                doubleclick.net
# 0                    parsely.com
# 0                    parsely.com
# 0                doubleclick.net
# 0                     amazon.com
# 0                doubleclick.net
# 0                    parsely.com
# 0                       litix.io
# 0           google-analytics.com
# 0           google-analytics.com
# 0           google-analytics.com
# 0                     omtrdc.net
# 0           google-analytics.com
# 0               youboranqs01.com
# 0           google-analytics.com
# 0                    conviva.com
# 0           google-analytics.com
# 0                    conviva.com
# 0           google-analytics.com
# 0           google-analytics.com
# 0               youboranqs01.com
# 0                       pluto.tv
# 0               youboranqs01.com

# %%
leaks[(leaks.leak_type=="url_leaks") & leaks.search.str.contains('nowcast')].url.iloc[10]
# Out:
# u'https://pubads.g.doubleclick.net/gampad/ads?sz=640x480%7C3x3&iu=%2F36117602%2Fhtv-wdsu.com%2Fnews%2Flive%2Fmidroll%2Fdvr_firetv&ciu_szs=300x250%2C728x90&gdfp_req=1&env=vp&ad_rule=1&output=xml_vmap1&unviewed_position_start=1&url=https%3A%2F%2Fwww.wdsu.com%2Fnowcast&description_url=https%3A%2F%2Fwww.wdsu.com%2Fnowcast&cmsid=2473396&vid=wdsuvodnowcast&cust_params=tool%3Dvideo%26pos%3Dmidroll%26site%3Dwdsu%26amzn_h%3Daax.amazon-adsystem.com%26amznslots%3DmVp17%26amzn_vid%3DQp8U-GNYbEyPywL1Et7KOzYAAAFqradP0gEAAA-qBHUdQ1g&correlator=14402880931089&ms=t39I5xdjNflF5o8MYA7POrU9bX81ryOstOqWMUkYN27UAPC5Jm6Zn6PwjtPEFmgchMoRrRCYpPyFvPy11CkZcWX4lO6W6wQN3IrVZnM8uMYMn2qaITDBEIgZ8FTnFmjoEWb7xV6_Gr2HPAgOIZ7MDVrT2r8ie0ZNJhmPzrtLkWTvmgTqHu86WdhqVbLtX9vJm8EKhLwoh8OvhE1keXRfxtO3qg6CnmOrE1m4jxGtmYybvx4JyFIyirg3Dd2wazoRyWv5-BRlsiyOqKgGkxYkqWQ8BvQKQbWoc2gxVNjcaQtSkW_otmni7dOfd_UKwTxqdTJePRBd9iJvcnFZKwI2Jw&js=ima-android.3.9.4&msid=com.hearst.android.wdsu&an=com.hearst.android.wdsu&mv=420607210.com.amazon.venezia&u_so=l&mpt=google%2Fexo.ext.ima&mpv=2.9.0&eid=319331040&sdkv=h.3.130.0%2Fn.android.3.9.4%2Fcom.hearst.android.wdsu&sdki=405&scor=182089673247654&osd=2&sdr=1&is_amp=0&hl=en&sdk_apis=7&omid_p=Google1%2Fandroid.3.9.4&dlt=1557691589964&idt=2695&dt=1557691592875'
