# %%
import LeakDetector
import pandas as pd
from glob import glob

# %%
from device_ids import TV_ID_MAP
from log_analysis import get_crawl_parameter
from crawl_ids import CrawlFireTVTop1KMITM
from df_utils import load_df

# %% [markdown]
# ## Load leaks
# - Run the following to detect and pickle leaks
#   - Detect on all crawls: `python2 title_leaks.py`
#   - Detect on a single crawl: `python2 title_leaks.py roku-data-20190508-013650`

# %%
leaks = load_df(CrawlFireTVTop1KMITM, "title_leak")

# %% [markdown]
# ### Manual false positive removal

# %% [markdown]
# We manually removed false positives that occur within the resource URLs, not sent as a title parameter.
# - "nowcast", "adtv" and "sbtv"
# - `http://www.christian-tv.org/tv/firetv/video/adtv.html`
# - `http://d27wx7ytq78mow.cloudfront.net/offair/sbtv-cb-v2/media_b3659760_0001.ts`
# - We filtered out channels where channel name is same as the video

# %%
from log_analysis import add_domain_column
add_domain_column(leaks)
title_leaks = leaks[~leaks.search.isin(["nowcast", "adtv", "sbtv"]) & (leaks.id_type !="Channel name")]
title_leaks = title_leaks[title_leaks.adblocked]
# title_leaks = leaks[leaks.id_type !="Channel name"][['channel_id', 'channel_name', 'id_type', 'encoding', 'search', 'leak_type', 'req_domain']].drop_duplicates()
print(title_leaks.channel_id.nunique(), "channels")
title_leaks[['channel_id', 'channel_name', 'category', 'id_type', 'encoding', 'search', 'leak_type', 'req_domain']].drop_duplicates()
# Out:
# (14, 'channels')
#                                           channel_id  \
# 0                             com.calkins.grahamksat
# 0                                   com.calkins.wral
# 0                                   com.calkins.wral
# 0                                    com.dmr.yuyu.tv
# 0  com.doapps.firetv.mln.MLN_6ae07dcb33ec3b7c814d...
# 0                            com.hillsongchannel.now
# 0                           com.mylocaltv.kjrhfiretv
# 0                           com.mylocaltv.wptvfiretv
# 0        com.planetdiscover.granite.phone.wkbwfiretv
# 0                                   com.zumobi.msnbc
# 0                                   com.zumobi.msnbc
# 0            net.screenmedia.popcornflix.kids.firetv
# 0            net.screenmedia.popcornflix.kids.firetv
# 0                           tv.accedo.cookingchannel
# 0                           tv.accedo.cookingchannel
# 0                            tv.accedo.travelchannel
# 0                            tv.accedo.travelchannel
# 0                                    tv.clasp.firetv
# 0                                    tv.clasp.firetv
# 0                                   tv.pluto.android
#
#                       channel_name     category  \
# 0                          KSAT TV         News
# 0                             WRAL         News
# 0                             WRAL         News
# 0           Yuyu - Movies &amp; TV  Movies & TV
# 0  WTMJ TODAY&#39;s TMJ4 Milwaukee         News
# 0             Hillsong Channel NOW    Lifestyle
# 0       KJRH 2 Works For You Tulsa         News
# 0     WPTV NewsChannel 5 West Palm         News
# 0   WKBW 7 Eyewitness News Buffalo         News
# 0                         NBC News         News
# 0                         NBC News         News
# 0                 Popcornflix Kids         Kids
# 0                 Popcornflix Kids         Kids
# 0                  Cooking Channel  Movies & TV
# 0                  Cooking Channel  Movies & TV
# 0                   Travel Channel  Movies & TV
# 0                   Travel Channel  Movies & TV
# 0    PopcornflixTM- Movies.TV.Free  Movies & TV
# 0    PopcornflixTM- Movies.TV.Free  Movies & TV
# 0      Pluto TV - It&#39;s Free TV  Movies & TV
#
#                                              id_type   encoding  \
# 0                      imdb_title_KSAT-TV Livestream  urlencode
# 0       imdb_title_Severe storms batter central U.S.  urlencode
# 0       imdb_title_Severe storms batter central U.S.  urlencode
# 0                             imdb_title_Mood Indigo  urlencode
# 0            imdb_title_Partly cloudy, cool Saturday  urlencode
# 0                          imdb_title_The Jesus Trek  unencoded
# 0  imdb_title_In the Kitchen with Fireside Grill:...  urlencode
# 0                            imdb_title_To The Point  urlencode
# 0  imdb_title_Graffiti Patio officially opens at ...  urlencode
# 0                       imdb_title_TODAY's Headlines  urlencode
# 0                       imdb_title_TODAY's Headlines  urlencode
# 0                              imdb_title_The Tuxedo  urlencode
# 0                              imdb_title_The Tuxedo  urlencode
# 0                        imdb_title_Raising the Heat  unencoded
# 0                        imdb_title_Raising the Heat  urlencode
# 0                          imdb_title_The Dead Files  unencoded
# 0                          imdb_title_The Dead Files  urlencode
# 0           imdb_title_Planes Trains and Automobiles  urlencode
# 0           imdb_title_Planes Trains and Automobiles  urlencode
# 0                imdb_title_The Adventures of Tintin  urlencode
#
#                                               search   leak_type  \
# 0                                 KSAT-TV Livestream  post_leaks
# 0                  Severe storms batter central U.S.   url_leaks
# 0                  Severe storms batter central U.S.  post_leaks
# 0                                        Mood Indigo   url_leaks
# 0                       Partly cloudy, cool Saturday  post_leaks
# 0                                     The Jesus Trek  post_leaks
# 0  In the Kitchen with Fireside Grill: Caribbean ...  post_leaks
# 0                                       To The Point  post_leaks
# 0     Graffiti Patio officially opens at Tappo Pizza  post_leaks
# 0                                  TODAY's Headlines   url_leaks
# 0                                  TODAY's Headlines  post_leaks
# 0                                         The Tuxedo  post_leaks
# 0                                         The Tuxedo   url_leaks
# 0                                   Raising the Heat  post_leaks
# 0                                   raising the heat  post_leaks
# 0                                     The Dead Files  post_leaks
# 0                                     the dead files  post_leaks
# 0                      Planes Trains and Automobiles   url_leaks
# 0                      Planes Trains and Automobiles  post_leaks
# 0                           The Adventures of Tintin   url_leaks
#
#               req_domain
# 0   google-analytics.com
# 0  scorecardresearch.com
# 0   google-analytics.com
# 0        spotxchange.com
# 0   google-analytics.com
# 0               litix.io
# 0   google-analytics.com
# 0   google-analytics.com
# 0   google-analytics.com
# 0             omtrdc.net
# 0   google-analytics.com
# 0   google-analytics.com
# 0       youboranqs01.com
# 0            conviva.com
# 0   google-analytics.com
# 0            conviva.com
# 0   google-analytics.com
# 0       youboranqs01.com
# 0   google-analytics.com
# 0       youboranqs01.com

# %%
from nb_utils import make_latex_table
print(make_latex_table(title_leaks[['channel_name', 'search', 'req_domain']].drop_duplicates(),
    caption="Title leaks in 100 random Fire TV channels",
    label="amazon_title_leaks"))
# Out:
# \begin{table}[H]
# %\centering
# %\resizebox{\columnwidth}{!}{%
# \begin{tabular}{lll}
# \toprule
#  Channel name                    & Search                                                     & Req domain            \\
# \midrule
#  KSAT TV                         & KSAT-TV Livestream                                         & google-analytics.com  \\
#  WRAL                            & Severe storms batter central U.S.                          & scorecardresearch.com \\
#  WRAL                            & Severe storms batter central U.S.                          & google-analytics.com  \\
#  Yuyu - Movies \&amp; TV          & Mood Indigo                                                & spotxchange.com       \\
#  WTMJ TODAY\&\#39;s TMJ4 Milwaukee & Partly cloudy, cool Saturday                               & google-analytics.com  \\
#  Hillsong Channel NOW            & The Jesus Trek                                             & litix.io              \\
#  KJRH 2 Works For You Tulsa      & In the Kitchen with Fireside Grill: Caribbean Jerk Chicken & google-analytics.com  \\
#  WPTV NewsChannel 5 West Palm    & To The Point                                               & google-analytics.com  \\
#  WKBW 7 Eyewitness News Buffalo  & Graffiti Patio officially opens at Tappo Pizza             & google-analytics.com  \\
#  NBC News                        & TODAY's Headlines                                          & omtrdc.net            \\
#  NBC News                        & TODAY's Headlines                                          & google-analytics.com  \\
#  Popcornflix Kids                & The Tuxedo                                                 & google-analytics.com  \\
#  Popcornflix Kids                & The Tuxedo                                                 & youboranqs01.com      \\
#  Cooking Channel                 & Raising the Heat                                           & conviva.com           \\
#  Cooking Channel                 & raising the heat                                           & google-analytics.com  \\
#  Travel Channel                  & The Dead Files                                             & conviva.com           \\
#  Travel Channel                  & the dead files                                             & google-analytics.com  \\
#  PopcornflixTM- Movies.TV.Free   & Planes Trains and Automobiles                              & youboranqs01.com      \\
#  PopcornflixTM- Movies.TV.Free   & Planes Trains and Automobiles                              & google-analytics.com  \\
#  Pluto TV - It\&\#39;s Free TV     & The Adventures of Tintin                                   & youboranqs01.com      \\
# \bottomrule
# \end{tabular}
# %}
# \caption{Title leaks in 100 random Fire TV channels}
# \label{tab:amazon_title_leaks}
# \end{table}

# %%
## Categories

# %%
title_leaks[['channel_id', 'category']].drop_duplicates()['category'].value_counts()
# Out:
# News           7
# Movies & TV    5
# Lifestyle      1
# Kids           1
# Name: category, dtype: int64

# %%
title_leaks[title_leaks.url.str.startswith('https://')]
# Out:
#     adblocked  adblocked_by_url     category  \
# 0        True              True         News
# 0        True              True         News
# 0        True              True         News
# 0        True              True         News
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True         News
# 0        True              True    Lifestyle
# 0        True              True    Lifestyle
# 0        True              True         News
# 0        True              True         News
# 0        True              True         News
# 0        True              True         News
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# 0        True              True         Kids
# ..        ...               ...          ...
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
# 0        True              True  Movies & TV
#
#                                            channel_id  \
# 0                              com.calkins.grahamksat
# 0                              com.calkins.grahamksat
# 0                                    com.calkins.wral
# 0                                    com.calkins.wral
# 0                                     com.dmr.yuyu.tv
# 0                                     com.dmr.yuyu.tv
# 0   com.doapps.firetv.mln.MLN_6ae07dcb33ec3b7c814d...
# 0                             com.hillsongchannel.now
# 0                             com.hillsongchannel.now
# 0                            com.mylocaltv.kjrhfiretv
# 0                            com.mylocaltv.wptvfiretv
# 0         com.planetdiscover.granite.phone.wkbwfiretv
# 0                                    com.zumobi.msnbc
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# 0             net.screenmedia.popcornflix.kids.firetv
# ..                                                ...
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                             tv.accedo.travelchannel
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                     tv.clasp.firetv
# 0                                    tv.pluto.android
#
#                        channel_name cookie decoded_data  disconnect_blocked  \
# 0                           KSAT TV                                    True
# 0                           KSAT TV                                    True
# 0                              WRAL                                    True
# 0                              WRAL                                    True
# 0            Yuyu - Movies &amp; TV                                    True
# 0            Yuyu - Movies &amp; TV                                    True
# 0   WTMJ TODAY&#39;s TMJ4 Milwaukee                                    True
# 0              Hillsong Channel NOW                                   False
# 0              Hillsong Channel NOW                                   False
# 0        KJRH 2 Works For You Tulsa                                    True
# 0      WPTV NewsChannel 5 West Palm                                    True
# 0    WKBW 7 Eyewitness News Buffalo                                    True
# 0                          NBC News                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                   False
# 0                  Popcornflix Kids                                   False
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                   False
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                   False
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# 0                  Popcornflix Kids                                    True
# ..                              ...    ...          ...                 ...
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0                    Travel Channel                                    True
# 0     PopcornflixTM- Movies.TV.Free                                   False
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                   False
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0     PopcornflixTM- Movies.TV.Free                                    True
# 0       Pluto TV - It&#39;s Free TV                                   False
#
#     disconnect_blocked_by_url         domain_by_dns  \
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True       spotxchange.com
# 0                        True       spotxchange.com
# 0                        True  google-analytics.com
# 0                       False              litix.io
# 0                       False              litix.io
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                       False      youboranqs01.com
# 0                       False      youboranqs01.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                       False      youboranqs01.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                       False      youboranqs01.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# 0                        True  google-analytics.com
# ..                        ...                   ...
# 0                        True  google-analytics.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                        True           conviva.com
# 0                       False      youboranqs01.com
# 0                        True
# 0                        True
# 0                       False      youboranqs01.com
# 0                        True
# 0                        True
# 0                        True
# 0                        True
# 0                        True
# 0                        True
# 0                        True
# 0                        True
# 0                       False      youboranqs01.com
#
#                           ...                          rank  referer  \
# 0                         ...                           679
# 0                         ...                           679
# 0                         ...                           577
# 0                         ...                           577
# 0                         ...                           470
# 0                         ...                           470
# 0                         ...                           996
# 0                         ...                          1019
# 0                         ...                          1019
# 0                         ...                          1114
# 0                         ...                           945
# 0                         ...                          1096
# 0                         ...                           109
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# 0                         ...                           165
# ..                        ...                           ...      ...
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           154
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                           162
# 0                         ...                             8
#
#               req_domain                                             search  \
# 0   google-analytics.com                                 KSAT-TV Livestream
# 0   google-analytics.com                                 KSAT-TV Livestream
# 0   google-analytics.com                  Severe storms batter central U.S.
# 0   google-analytics.com                  Severe storms batter central U.S.
# 0        spotxchange.com                                        Mood Indigo
# 0        spotxchange.com                                        Mood Indigo
# 0   google-analytics.com                       Partly cloudy, cool Saturday
# 0               litix.io                                     The Jesus Trek
# 0               litix.io                                     The Jesus Trek
# 0   google-analytics.com  In the Kitchen with Fireside Grill: Caribbean ...
# 0   google-analytics.com                                       To The Point
# 0   google-analytics.com     Graffiti Patio officially opens at Tappo Pizza
# 0   google-analytics.com                                  TODAY's Headlines
# 0   google-analytics.com                                         The Tuxedo
# 0       youboranqs01.com                                         The Tuxedo
# 0       youboranqs01.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0       youboranqs01.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0       youboranqs01.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# 0   google-analytics.com                                         The Tuxedo
# ..                   ...                                                ...
# 0   google-analytics.com                                     the dead files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0            conviva.com                                     The Dead Files
# 0       youboranqs01.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0       youboranqs01.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0   google-analytics.com                      Planes Trains and Automobiles
# 0       youboranqs01.com                           The Adventures of Tintin
#
#         status  tcp_dstport  tcp_stream                  time  \
# 0   TERMINATED          443          50  1557669726.644327000
# 0   TERMINATED          443          50  1557669748.595021000
# 0   TERMINATED          443          83  1557662703.635857000
# 0   TERMINATED          443          83  1557662678.737298000
# 0   TERMINATED          443          28  1557655176.195926000
# 0   TERMINATED          443          27  1557655176.196145000
# 0   TERMINATED          443          27  1557565041.862287000
# 0   TERMINATED          443          50  1557785664.983132000
# 0   TERMINATED          443          51  1557785665.308241000
# 0   TERMINATED          443          21  1557701840.903336000
# 0   TERMINATED          443          28  1557689323.881477000
# 0   TERMINATED          443          36  1557700714.054863000
# 0   TERMINATED          443         124  1557753548.520047000
# 0   TERMINATED          443          54  1557754771.690040000
# 0   TERMINATED          443         112  1557754850.603534000
# 0   TERMINATED          443         110  1557754850.600055000
# 0   TERMINATED          443         106  1557754850.382406000
# 0   TERMINATED          443         117  1557754853.408108000
# 0   TERMINATED          443         114  1557754853.420191000
# 0   TERMINATED          443         111  1557754850.600041000
# 0   TERMINATED          443         116  1557754853.407192000
# 0   TERMINATED          443          54  1557754772.091184000
# 0   TERMINATED          443         103  1557754850.374164000
# 0   TERMINATED          443          98  1557754849.921302000
# 0   TERMINATED          443          98  1557754849.369841000
# 0   TERMINATED          443          76  1557754786.509720000
# 0   TERMINATED          443          74  1557754786.388680000
# 0   TERMINATED          443          98  1557754834.409786000
# 0   TERMINATED          443          54  1557754785.907385000
# 0   TERMINATED          443          54  1557754785.396576000
# ..         ...          ...         ...                   ...
# 0   TERMINATED          443          54  1557789562.179008000
# 0   TERMINATED          443          23  1557789545.336914000
# 0   TERMINATED          443          23  1557789540.348025000
# 0   TERMINATED          443          23  1557789550.351884000
# 0   TERMINATED          443          23  1557789471.045392000
# 0   TERMINATED          443          23  1557789490.294977000
# 0   TERMINATED          443          23  1557789476.220123000
# 0   TERMINATED          443          23  1557789481.289676000
# 0   TERMINATED          443          23  1557789482.992915000
# 0   TERMINATED          443          23  1557789505.355622000
# 0   TERMINATED          443          23  1557789520.425376000
# 0   TERMINATED          443          23  1557789510.357638000
# 0   TERMINATED          443          23  1557789515.384570000
# 0   TERMINATED          443          23  1557789530.344514000
# 0   TERMINATED          443          23  1557789525.380230000
# 0   TERMINATED          443          23  1557789535.343764000
# 0   TERMINATED          443          23  1557789495.403314000
# 0   TERMINATED          443          35  1557634620.233838000
# 0   TERMINATED          443          17  1557634619.383484000
# 0   TERMINATED          443          38  1557634621.945379000
# 0   TERMINATED          443          34  1557634620.254692000
# 0   TERMINATED          443          32  1557634621.749450000
# 0   TERMINATED          443          37  1557634621.947455000
# 0   TERMINATED          443          17  1557634619.968881000
# 0   TERMINATED          443          17  1557634606.079062000
# 0   TERMINATED          443          17  1557634605.740228000
# 0   TERMINATED          443          17  1557634595.373207000
# 0   TERMINATED          443          32  1557634647.600798000
# 0   TERMINATED          443          32  1557634620.036500000
# 0   TERMINATED          443          56  1557751549.583285000
#
#                                                   url  \
# 0              https://ssl.google-analytics.com/batch
# 0              https://ssl.google-analytics.com/batch
# 0              https://ssl.google-analytics.com/batch
# 0              https://ssl.google-analytics.com/batch
# 0   https://search.spotxchange.com/vast/2.0/204812...
# 0   https://search.spotxchange.com/vast/2.0/204812...
# 0              https://ssl.google-analytics.com/batch
# 0   https://sfrc0h2ursbel1jbo6s82jap5.litix.io/and...
# 0   https://sfrc0h2ursbel1jbo6s82jap5.litix.io/and...
# 0              https://ssl.google-analytics.com/batch
# 0              https://ssl.google-analytics.com/batch
# 0              https://ssl.google-analytics.com/batch
# 0              https://ssl.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0   https://nqs-nl1-c2.youboranqs01.com/init?timem...
# 0   https://nqs-nl1-c2.youboranqs01.com/init?timem...
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0   https://nqs-nl1-c2.youboranqs01.com/start?time...
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0   https://nqs-nl1-c2.youboranqs01.com/start?time...
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# ..                                                ...
# 0              https://ssl.google-analytics.com/batch
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://9752421f6e38968e849bee2ad521d2f347f7eb...
# 0   https://nqs-nl1-c2.youboranqs01.com/init?timem...
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0   https://nqs-nl1-c2.youboranqs01.com/start?time...
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0              https://www.google-analytics.com/batch
# 0   https://nqs-nl8-c15.youboranqs01.com/start?par...
#
#                                            user_agent
# 0   GoogleAnalytics/12.4.51 (Linux; U; Android 5.1...
# 0   GoogleAnalytics/12.4.51 (Linux; U; Android 5.1...
# 0   GoogleAnalytics/12.4.51 (Linux; U; Android 5.1...
# 0   GoogleAnalytics/12.4.51 (Linux; U; Android 5.1...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   GoogleAnalytics/11.0.20 (Linux; U; Android 5.1...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   GoogleAnalytics/11.0.20 (Linux; U; Android 5.1...
# 0   GoogleAnalytics/11.0.20 (Linux; U; Android 5.1...
# 0   GoogleAnalytics/11.0.20 (Linux; U; Android 5.1...
# 0   GoogleAnalytics/12.4.51 (Linux; U; Android 5.1...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# ..                                                ...
# 0   GoogleAnalytics/10.2.98 (Linux; U; Android 5.1...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
# 0   Dalvik/2.1.0 (Linux; U; Android 5.1.1; AFTT Bu...
#
# [104 rows x 40 columns]

# %%
title_leaks[['channel_id', 'tcp_dstport']].drop_duplicates()['tcp_dstport'].value_counts()
# Out:
# 443    14
# 80      2
# Name: tcp_dstport, dtype: int64

# %%
title_leaks[['channel_id', 'channel_name', 'req_domain', 'tcp_dstport']].drop_duplicates()
# Out:
#                                           channel_id  \
# 0                             com.calkins.grahamksat
# 0                                   com.calkins.wral
# 0                                   com.calkins.wral
# 0                                    com.dmr.yuyu.tv
# 0  com.doapps.firetv.mln.MLN_6ae07dcb33ec3b7c814d...
# 0                            com.hillsongchannel.now
# 0                           com.mylocaltv.kjrhfiretv
# 0                           com.mylocaltv.wptvfiretv
# 0        com.planetdiscover.granite.phone.wkbwfiretv
# 0                                   com.zumobi.msnbc
# 0                                   com.zumobi.msnbc
# 0            net.screenmedia.popcornflix.kids.firetv
# 0            net.screenmedia.popcornflix.kids.firetv
# 0                           tv.accedo.cookingchannel
# 0                           tv.accedo.cookingchannel
# 0                            tv.accedo.travelchannel
# 0                            tv.accedo.travelchannel
# 0                                    tv.clasp.firetv
# 0                                    tv.clasp.firetv
# 0                                   tv.pluto.android
#
#                       channel_name             req_domain  tcp_dstport
# 0                          KSAT TV   google-analytics.com          443
# 0                             WRAL  scorecardresearch.com           80
# 0                             WRAL   google-analytics.com          443
# 0           Yuyu - Movies &amp; TV        spotxchange.com          443
# 0  WTMJ TODAY&#39;s TMJ4 Milwaukee   google-analytics.com          443
# 0             Hillsong Channel NOW               litix.io          443
# 0       KJRH 2 Works For You Tulsa   google-analytics.com          443
# 0     WPTV NewsChannel 5 West Palm   google-analytics.com          443
# 0   WKBW 7 Eyewitness News Buffalo   google-analytics.com          443
# 0                         NBC News             omtrdc.net           80
# 0                         NBC News   google-analytics.com          443
# 0                 Popcornflix Kids   google-analytics.com          443
# 0                 Popcornflix Kids       youboranqs01.com          443
# 0                  Cooking Channel            conviva.com          443
# 0                  Cooking Channel   google-analytics.com          443
# 0                   Travel Channel            conviva.com          443
# 0                   Travel Channel   google-analytics.com          443
# 0    PopcornflixTM- Movies.TV.Free       youboranqs01.com          443
# 0    PopcornflixTM- Movies.TV.Free   google-analytics.com          443
# 0      Pluto TV - It&#39;s Free TV       youboranqs01.com          443
