# %%
import LeakDetector
import numpy as np
import pandas as pd
from os.path import isdir, join, basename
from datetime import datetime
from glob import glob

# %%
from device_ids import TV_ID_MAP_V1
from log_analysis import get_crawl_parameter, get_crawl_data_path, get_ott_device_mac
from crawl_ids import CrawlRokuTop1KMITM
from df_utils import load_df
from nb_utils import make_latex_table

from ott_leaks import run_leak_detection, DEVICE_ID_NAMES, print_leak_stats, remove_ch_name_url_false_positives

# %% [markdown]
# ## Load leaks
# - Run the following to detect and pickle leaks
#   - Detect on all crawls: `python2 detect_leaks.py`
#   - Detect on a single crawl: `python2 detect_leaks.py roku-data-20190508-013650`

# %%
leaks_roku = load_df(CrawlRokuTop1KMITM, "leak")

# %%
leaks_roku = load_df(CrawlRokuTop1KMITM, "leak")
leaks_roku = leaks_roku[leaks_roku.id_type!="Build Number"]
leaks_roku = leaks_roku[leaks_roku.req_domain!="roku.com"]
id_leaks_roku = leaks_roku[leaks_roku.id_type.isin(DEVICE_ID_NAMES)]
df = print_leak_stats(leaks_roku)
df
# Out:
#              ID  Num. of leaks  Num. of channels
# 0         AD ID          12739               359
# 1  Channel name          10041               211
# 2          City            273                35
# 3         State            164                26
# 4           Zip            298                43
# 5     Serial No           4216               114
# 6         Email             15                 5

# %%
print(make_latex_table(
    df, caption="Overview of information leakage detected in Roku-Top1K-NoMITM crawl",
    label="leaks_roku"))
# Out:
# \begin{table}[H]
# %\centering
# %\resizebox{\columnwidth}{!}{%
# \begin{tabular}{lrr}
# \toprule
#  Id           &   Num. of leaks &   Num. of channels \\
# \midrule
#  AD ID        &           12739 &                359 \\
#  Channel name &           10041 &                211 \\
#  City         &             273 &                 35 \\
#  State        &             164 &                 26 \\
#  Zip          &             298 &                 43 \\
#  Serial No    &            4216 &                114 \\
#  Email        &              15 &                  5 \\
# \bottomrule
# \end{tabular}
# %}
# \caption{Overview of information leakage detected in Roku-Top1K-NoMITM crawl}
# \label{tab:leaks_roku}
# \end{table}

# %%
## Pi-Hole-Block

# %% [markdown]
# ## ID Leaks
# - Exclude non-Id search terms

# %%
leaks_roku.adblocked.value_counts()
# Out:
# True     21304
# False     6442
# Name: adblocked, dtype: int64

# %% [markdown]
# ### Email sent on channel (for registration)
# - email address sant to  http://api.qello.com/users/register/ for registration purposes
# - crawler actually clicked the dialog to allow email address to be accessed from Roku

# %%
leaks_roku[leaks_roku.id_type.isin(["Email", "Unknown"])]
# Out:
#    adblocked  adblocked_by_url category channel_id    channel_name cookie  \
# 0      False             False   Sports     256015           AHLTV
# 0      False             False   Sports     256015           AHLTV
# 0      False             False   Sports     256015           AHLTV
# 0      False             False   Sports     256015           AHLTV
# 0      False             False   Sports     108645        HockeyTV
# 0      False             False   Sports     108645        HockeyTV
# 0      False             False   Sports     108645        HockeyTV
# 0      False             False   Sports     108645        HockeyTV
# 0      False             False   Sports      70391      MotorTrend
# 0      False             False   Comedy     244040        RiffTrax
# 0      False             False   Comedy     244040        RiffTrax
# 0      False             False    Music      40299  Stingray Qello
# 0      False             False    Music      40299  Stingray Qello
# 0      False             False    Music      40299  Stingray Qello
# 0      False             False    Music      40299  Stingray Qello
#
#   decoded_data  disconnect_blocked  disconnect_blocked_by_url  \
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
# 0                            False                      False
#
#             domain_by_dns              ...               rank  referer  \
# 0         watchtheahl.com              ...                680
# 0         watchtheahl.com              ...                680
# 0         watchtheahl.com              ...                680
# 0         watchtheahl.com              ...                680
# 0            hockeytv.com              ...               1230
# 0            hockeytv.com              ...               1230
# 0            hockeytv.com              ...               1230
# 0            hockeytv.com              ...               1230
# 0  motortrendondemand.com              ...                150
# 0          oddconnect.com              ...               1022
# 0          oddconnect.com              ...               1022
# 0               qello.com              ...                498
# 0               qello.com              ...                498
# 0               qello.com              ...                498
# 0               qello.com              ...                498
#
#                req_domain              search      status  tcp_dstport  \
# 0         watchtheahl.com  macyli47@gmail.com  TERMINATED          443
# 0         watchtheahl.com  macyli47@gmail.com  TERMINATED          443
# 0         watchtheahl.com  macyli47@gmail.com  TERMINATED          443
# 0         watchtheahl.com  macyli47@gmail.com  TERMINATED          443
# 0            hockeytv.com  macyli47@gmail.com  TERMINATED          443
# 0            hockeytv.com  macyli47@gmail.com  TERMINATED          443
# 0            hockeytv.com  macyli47@gmail.com  TERMINATED          443
# 0            hockeytv.com  macyli47@gmail.com  TERMINATED          443
# 0  motortrendondemand.com  macyli47@gmail.com  TERMINATED           80
# 0          oddconnect.com  macyli47@gmail.com  TERMINATED          443
# 0          oddconnect.com  macyli47@gmail.com  TERMINATED          443
# 0               qello.com  macyli47@gmail.com  TERMINATED           80
# 0               qello.com  macyli47@gmail.com  TERMINATED           80
# 0               qello.com  macyli47@gmail.com  TERMINATED           80
# 0               qello.com  macyli47@gmail.com  TERMINATED           80
#
#    tcp_stream                  time  \
# 0          83  1558854805.366032000
# 0         103  1558854839.136287000
# 0         152  1558854936.908638000
# 0         172  1558854970.701874000
# 0         146  1558924721.145332000
# 0          78  1558924589.500667000
# 0          98  1558924623.258755000
# 0         166  1558924754.927272000
# 0         102  1559164962.760976000
# 0         118  1558923964.636551000
# 0         186  1558924093.955345000
# 0         102  1559061824.215103000
# 0         188  1559061955.701806000
# 0         128  1559061858.016539000
# 0         214  1559061989.498758000
#
#                                                  url  \
# 0  https://ott.watchtheahl.com/user_lookup?email=...
# 0  https://ott.watchtheahl.com/user_lookup?email=...
# 0  https://ott.watchtheahl.com/user_lookup?email=...
# 0  https://ott.watchtheahl.com/user_lookup?email=...
# 0  https://ott.hockeytv.com/user_lookup?email=mac...
# 0  https://ott.hockeytv.com/user_lookup?email=mac...
# 0  https://ott.hockeytv.com/user_lookup?email=mac...
# 0  https://ott.hockeytv.com/user_lookup?email=mac...
# 0  http://api.motortrendondemand.com/api/v2/profi...
# 0  https://oddconnect.com/api/device_users/macyli...
# 0  https://oddconnect.com/api/device_users/macyli...
# 0               http://api.qello.com/users/register/
# 0               http://api.qello.com/users/register/
# 0               http://api.qello.com/users/register/
# 0               http://api.qello.com/users/register/
#
#                      user_agent
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
# 0  Roku/DVP-9.0 (519.00E04142A)
#
# [15 rows x 40 columns]

# %% [markdown]
# ### Adblocked status
# - 4853 of the 6314 (76%) ID leaks are to domains flagged by ad blocker lists
# - 38 if the 76 domains IDs leaked to are flagged by ad blocker lists

# %%
id_leaks_roku.adblocked.value_counts()
# Out:
# True     14377
# False     2578
# Name: adblocked, dtype: int64

# %%
leaks_roku.adblocked.value_counts()
# Out:
# True     21304
# False     6442
# Name: adblocked, dtype: int64

# %%
id_leaks_roku.drop_duplicates("req_domain").adblocked.value_counts()
# Out:
# True     44
# False    38
# Name: adblocked, dtype: int64

# %%
leaks_roku.drop_duplicates("req_domain").adblocked.value_counts()
# Out:
# False    83
# True     48
# Name: adblocked, dtype: int64

# %% [markdown]
# ### Leaked IDs

# %%
leaks_roku.id_type.value_counts()
# Out:
# AD ID           12739
# Channel name    10041
# Serial No        4216
# Zip               298
# City              273
# State             164
# Email              15
# Name: id_type, dtype: int64

# %% [markdown]
# ### Leak location

# %%
leaks_roku.leak_type.value_counts()
# Out:
# url_leaks         22254
# post_leaks         4458
# referrer_leaks      998
# cookie_leaks         36
# Name: leak_type, dtype: int64

# %% [markdown]
# ### Leak encodings

# %%
leaks_roku.encoding.value_counts()
# Out:
# unencoded              20794
# sha1                    2363
# md5                     2358
# urlencode               2148
# base64                    71
# sha256                    10
# urlencode-urlencode        2
# Name: encoding, dtype: int64
