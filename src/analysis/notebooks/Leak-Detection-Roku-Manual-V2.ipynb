# %%
import LeakDetector
import numpy as np
import pandas as pd
from os.path import isdir, join, basename
from datetime import datetime
from glob import glob

# %%
from device_ids import TV_ID_MAP
from log_analysis import get_crawl_parameter
from crawl_ids import CrawlRokuManualV2
from df_utils import load_df
from nb_utils import make_latex_table

from ott_leaks import run_leak_detection, DEVICE_ID_NAMES, print_leak_stats, remove_ch_name_url_false_positives


pd.set_option("display.max_colwidth",500)
pd.set_option("display.max_rows",500)

# %% [markdown]
# ## Load leaks
# - Run the following to detect and pickle leaks
#   - Detect on all crawls: `python2 detect_leaks.py`
#   - Detect on a single crawl: `python2 detect_leaks.py roku-data-20190508-013650`

# %%
leaks_roku = load_df(CrawlRokuManualV2, "leak")
openwpm_leaks_roku = load_df(CrawlRokuManualV2, "openwpm_leak")
leaks_roku = leaks_roku[leaks_roku.id_type!="Build Number"]
len(leaks_roku), len(openwpm_leaks_roku)
# Out:
# (11923, 2074)

# %%
remove_ch_name_url_false_positives(leaks_roku)  # this is part of the leak detection flow now
leaks_roku = leaks_roku[leaks_roku.req_domain!="roku.com"]
id_leaks_roku = leaks_roku[leaks_roku.id_type.isin(DEVICE_ID_NAMES)
                           | leaks_roku.id_type.str.contains("password", case=False)
                           | leaks_roku.id_type.str.contains("email", case=False)
                           | leaks_roku.id_type.str.contains("cc", case=False)
                           | leaks_roku.id_type.str.contains("password", case=False)]
df = print_leak_stats(leaks_roku)
df
# Out:
#                  ID  Num. of leaks  Num. of channels
# 0             AD ID           3478                12
# 1      Channel name           8044                14
# 2    directtv_email             11                 2
# 3       Device Name            212                 4
# 4     Profile Email              1                 1
# 5         Serial No              1                 1
# 6       Profile Zip            137                 1
# 7               Zip             37                 1
# 8  Profile Password              2                 1

# %%
from log_analysis import add_domain_column
add_domain_column(openwpm_leaks_roku)

# %%
openwpm_leaks_roku[openwpm_leaks_roku.id_type !="Channel name"][['channel_name', 'id_type', 'encoding', 'search', 'leak_type', 'req_domain']].drop_duplicates()
# Out:
#   channel_name        id_type   encoding                search  leak_type  \
# 0          ABC           City  unencoded             princeton  url_leaks
# 1      Hotstar  Profile Email     sha256  baaaaaab54@gmail.com  url_leaks
# 1      Netflix  Profile Email     sha256  baaaaaab54@gmail.com  url_leaks
# 0      Netflix  Profile Email     sha256  baaaaaab54@gmail.com  url_leaks
# 0      Netflix  Profile Email     sha256  baaaaaab54@gmail.com  url_leaks
# 1      Netflix  Profile Email     sha256  baaaaaab54@gmail.com  url_leaks
# 1      Netflix  Profile Email     sha256  baaaaaab54@gmail.com  url_leaks
# 0      Netflix    Profile Zip  unencoded                 40505  url_leaks
#
#                req_domain
# 0                  go.com
# 1  gravityrd-services.com
# 1    googleadservices.com
# 0             nflximg.net
# 0            facebook.com
# 1              google.com
# 1         doubleclick.net
# 0           nflxvideo.net

# %%
id_leaks_roku[id_leaks_roku.id_type !="Channel name"][['channel_name', 'id_type', 'encoding', 'search', 'leak_type', 'req_domain']].drop_duplicates()
# Out:
#                     channel_name           id_type   encoding  \
# 0                            ABC             AD ID       sha1
# 2                            ABC             AD ID        md5
# 0                       ABC News             AD ID  unencoded
# 0                          Bravo             AD ID       sha1
# 1                          Bravo             AD ID        md5
# 0                          Bravo             AD ID  unencoded
# 2                          Bravo             AD ID  unencoded
# 0                          Bravo             AD ID  unencoded
# 0                          Bravo             AD ID  unencoded
# 0                Cartoon Network             AD ID       sha1
# 1                Cartoon Network             AD ID        md5
# 0                Cartoon Network             AD ID  unencoded
# 0                Cartoon Network             AD ID  unencoded
# 0                Cartoon Network             AD ID  unencoded
# 0                    DIRECTV NOW             AD ID       sha1
# 2                    DIRECTV NOW             AD ID        md5
# 0                    DIRECTV NOW    directtv_email  unencoded
# 0               Fox News Channel             AD ID       sha1
# 1               Fox News Channel             AD ID        md5
# 2               Fox News Channel             AD ID  unencoded
# 0                        Hotstar     Profile Email     sha256
# 0                           Hulu             AD ID  unencoded
# 0                           Hulu             AD ID  unencoded
# 2                           Hulu             AD ID  unencoded
# 0                       NBC News             AD ID       sha1
# 1                       NBC News             AD ID        md5
# 0                       NBC News             AD ID  unencoded
# 0                     NBC Sports             AD ID  unencoded
# 0                     NBC Sports             AD ID  unencoded
# 0                     NBC Sports             AD ID  unencoded
# 0                     NBC Sports             AD ID  unencoded
# 1                     NBC Sports             AD ID  unencoded
# 1                     NBC Sports             AD ID  unencoded
# 0                     NBC Sports             AD ID  unencoded
# 0                        Netflix         Serial No  unencoded
# 0                            PBS             AD ID       sha1
# 1                            PBS             AD ID        md5
# 0                       Sling TV             AD ID  unencoded
# 0                       Sling TV             AD ID  unencoded
# 0                       Sling TV             AD ID  unencoded
# 1  fuboTV Watch Live Sports & TV    directtv_email     base64
# 4  fuboTV Watch Live Sports & TV             AD ID  unencoded
# 0  fuboTV Watch Live Sports & TV             AD ID  unencoded
# 1  fuboTV Watch Live Sports & TV    directtv_email  unencoded
# 0  fuboTV Watch Live Sports & TV  Profile Password  unencoded
# 1  fuboTV Watch Live Sports & TV    directtv_email  unencoded
#
#                                  search       leak_type  \
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 2  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 2  4489bf66-6dc7-5173-a700-bdb751bc6cf2      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 2  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0                    macyli36@gmail.com      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 2  4489bf66-6dc7-5173-a700-bdb751bc6cf2      post_leaks
# 0                  baaaaaab54@gmail.com      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 2  4489bf66-6dc7-5173-a700-bdb751bc6cf2      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2  referrer_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0                          YG00EV851013      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1                    macyli36@gmail.com      post_leaks
# 4  4489bf66-6dc7-5173-a700-bdb751bc6cf2      post_leaks
# 0  4489bf66-6dc7-5173-a700-bdb751bc6cf2       url_leaks
# 1                    macyli36@gmail.com      post_leaks
# 0                             Baaaaaab2      post_leaks
# 1                    macyli36@gmail.com      post_leaks
#
#                req_domain
# 0   scorecardresearch.com
# 2   scorecardresearch.com
# 0         doubleclick.net
# 0   scorecardresearch.com
# 1   scorecardresearch.com
# 0               fwmrm.net
# 2              omtrdc.net
# 0              demdex.net
# 0              omtrdc.net
# 0   scorecardresearch.com
# 1   scorecardresearch.com
# 0              turner.com
# 0            akamaihd.net
# 0            auditude.com
# 0   scorecardresearch.com
# 2   scorecardresearch.com
# 0               dtvce.com
# 0   scorecardresearch.com
# 1   scorecardresearch.com
# 2              segment.io
# 0  gravityrd-services.com
# 0                hulu.com
# 0        imrworldwide.com
# 2           brightline.tv
# 0   scorecardresearch.com
# 1   scorecardresearch.com
# 0               fwmrm.net
# 0             moatads.com
# 0              demdex.net
# 0               fwmrm.net
# 0            auditude.com
# 1            auditude.com
# 1              omtrdc.net
# 0              omtrdc.net
# 0             netflix.com
# 0   scorecardresearch.com
# 1   scorecardresearch.com
# 0              omtrdc.net
# 0              demdex.net
# 0              movetv.com
# 1              segment.io
# 4              segment.io
# 0                 fubo.tv
# 1              segment.io
# 0                 fubo.tv
# 1                 fubo.tv

# %%
print(make_latex_table(
    df, caption="Overview of information leakage detected in Roku-Top1K-NoMITM crawl",
    label="leaks_roku"))
# Out:
# \begin{table}[H]
# %\centering
# %\resizebox{\columnwidth}{!}{%
# \begin{tabular}{lrr}
# \toprule
#  Id               &   Num. of leaks &   Num. of channels \\
# \midrule
#  AD ID            &            3478 &                 12 \\
#  Channel name     &            8044 &                 14 \\
#  directtv\_email   &              11 &                  2 \\
#  Device Name      &             212 &                  4 \\
#  Profile Email    &               1 &                  1 \\
#  Serial No        &               1 &                  1 \\
#  Profile Zip      &             137 &                  1 \\
#  Zip              &              37 &                  1 \\
#  Profile Password &               2 &                  1 \\
# \bottomrule
# \end{tabular}
# %}
# \caption{Overview of information leakage detected in Roku-Top1K-NoMITM crawl}
# \label{tab:leaks_roku}
# \end{table}

# %% [markdown]
# ### Leak location

# %%
leaks_roku.leak_type.value_counts()
# Out:
# url_leaks         11191
# post_leaks          574
# referrer_leaks      114
# cookie_leaks         44
# Name: leak_type, dtype: int64

# %% [markdown]
# ### Leak encodings

# %%
leaks_roku.encoding.value_counts()
# Out:
# unencoded    10227
# sha1           796
# md5            796
# urlencode       75
# base64          28
# sha256           1
# Name: encoding, dtype: int64

# %% [markdown]
# ### Top trackers

# %%
from nb_utils import get_popular_domains_from_tcp_conns
tcp = load_df(CrawlRokuManualV2, "tcp_conn")
df = get_popular_domains_from_tcp_conns(tcp[tcp.adblocked])
df
# Out:
#                    domain  Num. of channels
# 21        doubleclick.net                23
# 34  googlesyndication.com                18
# 51  scorecardresearch.com                12
# 20             demdex.net                10
# 37            innovid.com                 9
# 36       imrworldwide.com                 8
# 48             omtrdc.net                 7
# 15            conviva.com                 7
# 28              fwmrm.net                 6
# 3               adobe.com                 6

# %%
print make_latex_table(df, caption="Most prevalent trackers in the Roku manual crawl", label="tab:top_trackers_roku_manual_v2")
# Out:
# \begin{table}[H]
# %\centering
# %\resizebox{\columnwidth}{!}{%
# \begin{tabular}{lr}
# \toprule
#  Domain                &   Num. of channels \\
# \midrule
#  doubleclick.net       &                 23 \\
#  googlesyndication.com &                 18 \\
#  scorecardresearch.com &                 12 \\
#  demdex.net            &                 10 \\
#  innovid.com           &                  9 \\
#  imrworldwide.com      &                  8 \\
#  omtrdc.net            &                  7 \\
#  conviva.com           &                  7 \\
#  fwmrm.net             &                  6 \\
#  adobe.com             &                  6 \\
# \bottomrule
# \end{tabular}
# %}
# \caption{Most prevalent trackers in the Roku manual crawl}
# \label{tab:tab:top_trackers_roku_manual_v2}
# \end{table}
